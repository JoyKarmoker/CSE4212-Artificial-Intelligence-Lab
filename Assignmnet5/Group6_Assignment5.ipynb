# %% [markdown]
# # Importing Necessary Modules

# %%
from google.colab import drive
from tensorflow.keras.utils import plot_model
import os
import cv2
import matplotlib.pyplot as plt
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications import vgg16, ResNet50
from keras.layers import Conv2D, Input, Dense, Activation, MaxPooling2D, Flatten, AveragePooling2D, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from keras.utils import to_categorical
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Fetching Peace and Thumbs Up Data, Labeling Peace as 0, and Thumbs Up as 1

# %%
#reading data and labeling it
DIRECTORY = '/content/drive/MyDrive/thumbsup_peace'
CATEGORIES = ['peace_test', 'peace_train', 'thumbsup_test', 'thumbsup_train']
train_data = []
test_data = []
test_count = 0
train_count = 0
for category in CATEGORIES:
  folder = os.path.join(DIRECTORY, category)
  label = CATEGORIES.index(category) // 2
  # print(label)
  splited_name = category.split('_')
  # print(splited_name[1])

  if(splited_name[1] == "train"):
    # print(category)
      for img in os.listdir(folder):
        image = os.path.join(folder, img)
        image_arr = cv2.imread(image)
        image_arr = cv2.resize(image_arr, (224, 224))
        train_data.append([image_arr, label])
        train_count = train_count+1
  else:
    # print("test")
    for img in os.listdir(folder):
      image = os.path.join(folder, img)
      image_arr = cv2.imread(image)
      image_arr = cv2.resize(image_arr, (224, 224))
      test_data.append([image_arr, label])
      test_count = test_count+1

print('Number of total train data: ', train_count)
print('Number of test data: ', test_count)
# Out:
# Number of total train data:  650
# Number of test data:  161

# %% [markdown]
# # Making np array X_train_val and Y_train_val from train data

# %%
#making x and y from read data and label
random.shuffle(train_data)
x_train_val = []
y_train_val = []

for features,label in train_data:
  x_train_val.append(features)
  y_train_val.append(label)

#converitn x and y list to np array
x_train_val = np.array(x_train_val)
y_train_val = np.array(y_train_val)

# %% [markdown]
# # Making np array x_tes and y_test from test data

# %%
#making x and y from read data and label
random.shuffle(test_data)
x_test = []
y_test = []

for features,label in test_data:
  x_test.append(features)
  y_test.append(label)

#converitn x and y list to np array
x_test = np.array(x_test)
y_test = np.array(y_test)
print(len(y_test))
# Out:
# 161

# %% [markdown]
# # Plotting X_train_val

# %%
flatten_images = x_train_val.ravel()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(flatten_images, color='black', alpha=0.7)
plt.title('Histogram of Pixel Of X_train_val Intensities Before Normalization', fontsize=16)
plt.xlabel('Pixel Intensity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(True)
plt.show()

# Print the highest and lowest intensity of pixel
print(f'Highest intensity of pixel: {np.max(flatten_images)}')
print(f'Lowest intensity of pixel: {np.min(flatten_images)}')
# Out:
# Highest intensity of pixel: 255
# Lowest intensity of pixel: 0

# %% [markdown]
# # Plotting X_test

# %%
flatten_images = x_test.ravel()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(flatten_images, color='black', alpha=0.7)
plt.title('Histogram of Pixel Of X_test Intensities Before Normalization', fontsize=16)
plt.xlabel('Pixel Intensity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(True)
plt.show()

# Print the highest and lowest intensity of pixel
print(f'Highest intensity of pixel: {np.max(flatten_images)}')
print(f'Lowest intensity of pixel: {np.min(flatten_images)}')
# Out:
# Highest intensity of pixel: 255
# Lowest intensity of pixel: 0

# %% [markdown]
# #Normalizing x_train_val and Plotting

# %%
#normalizing x
x_train_val = x_train_val/255.0

# Assuming x is your array of images with shape (1012, 224, 224, 3)
# Flatten each image and concatenate them into a single array
flatten_images = x_train_val.ravel()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(flatten_images, color='black', alpha=0.7)
plt.title('Histogram of x_train_val Pixel Intensities After Normalization', fontsize=16)
plt.xlabel('Pixel Intensity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(True)
plt.show()

# Print the highest and lowest intensity of pixel
print(f'Highest intensity of pixel: {np.max(flatten_images)}')
print(f'Lowest intensity of pixel: {np.min(flatten_images)}')
# Out:
# Highest intensity of pixel: 1.0
# Lowest intensity of pixel: 0.0

# %% [markdown]
# #Normalizing x_test and Plotting

# %%
#normalizing x
x_test = x_test/255.0

# Assuming x is your array of images with shape (1012, 224, 224, 3)
# Flatten each image and concatenate them into a single array
flatten_images = x_test.ravel()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(flatten_images, color='black', alpha=0.7)
plt.title('Histogram of x_test Pixel Intensities After Normalization', fontsize=16)
plt.xlabel('Pixel Intensity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(True)
plt.show()

# Print the highest and lowest intensity of pixel
print(f'Highest intensity of pixel: {np.max(flatten_images)}')
print(f'Lowest intensity of pixel: {np.min(flatten_images)}')
# Out:
# Highest intensity of pixel: 1.0
# Lowest intensity of pixel: 0.0

# %% [markdown]
# # Splitting Train and Validation Set

# %%
# x_train, x_val, y_train, y_val  = train_test_split(x_train_val, y_train_val, test_size=0.1)
x_train = x_train_val[:int(len(x_train_val)*.9)]
x_val = x_train_val[-int(len(x_train_val)*.1):]
y_train = y_train_val[:int(len(y_train_val)*.9)]
y_val = y_train_val[-int(len(y_train_val)*.1):]

# %% [markdown]
# # Plotting y_train, y_val and y_test

# %%
plt.figure(figsize=(10, 6))
plt.hist(y_train, color='Black', alpha=0.7)
plt.title('Number Of thumbs and Peace Sign in Train Set', fontsize=16)
plt.xlabel('Class       Peace(0)          ThumbsUp(1)', fontsize=14)
plt.ylabel('Number Of Objects In Each Class', fontsize=14)
plt.grid('true')

# Get the counts of objects in each class
counts = np.bincount(y_train)
for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(y_val, color='Black', alpha=0.7)
plt.title('Number Of thumbs and Peace Sign in Validation Set', fontsize=16)
plt.xlabel('Class       Peace(0)          ThumbsUp(1)', fontsize=14)
plt.ylabel('Number Of Objects In Each Class', fontsize=14)
plt.grid('true')
counts = np.bincount(y_val)
for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(y_test, color='Black', alpha=0.7)
plt.title('Number Of thumbs and Peace Sign in Test Set', fontsize=16)
plt.xlabel('Class       Peace(0)          ThumbsUp(1)', fontsize=14)
plt.ylabel('Number Of Objects In Each Class', fontsize=14)
plt.grid('true')
counts = np.bincount(y_test)
for i, count in enumerate(counts):
    plt.text(i, count, str(count), ha='center', va='bottom')
plt.show()

# %% [markdown]
# # Printing The Shapes of Train, Test and Validation Data

# %%
print('Shape of x_train', np.shape(x_train))
print('Shape of x_val', np.shape(x_val))
print('Shape of x_test', np.shape(x_test))
print('Shape of y_train', np.shape(y_train))
print('Shape of y_val', np.shape(y_val))
print('Shape of y_test', np.shape(y_test))
# Out:
# Shape of x_train (585, 224, 224, 3)
# Shape of x_val (65, 224, 224, 3)
# Shape of x_test (161, 224, 224, 3)
# Shape of y_train (585,)
# Shape of y_val (65,)
# Shape of y_test (161,)

# %% [markdown]
# # Extending Vgg16

# %%
vgg16_model = tf.keras.applications.VGG16(
    weights='imagenet',  # You can use 'imagenet' to load ImageNet pre-trained weights
    include_top=False,   # Exclude the top (fully connected) layers
    input_shape=(224, 224, 3)  # Specify the input shape of your images
)


model = tf.keras.models.Sequential()
model.add(vgg16_model)
model.add(tf.keras.layers.Flatten())
# model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(2, activation='sigmoid'))

model.layers[0].trainable = False
model.compile(loss='sparse_categorical_crossentropy', optimizer=keras.optimizers.Adam(
    learning_rate=0.001), metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 2)                 50178
#
# =================================================================
# Total params: 14764866 (56.32 MB)
# Trainable params: 50178 (196.01 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# # Showing Model Architecture

# %%
# Plot and display the model architecture in the notebook
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Trainning The model with x and y

# %%
history = model.fit(x_train, y_train, epochs=20, validation_data=(x_val, y_val), batch_size=16)
# Out:
# Epoch 1/20
# 37/37 [==============================] - 406s 11s/step - loss: 0.5100 - accuracy: 0.7966 - val_loss: 0.2610 - val_accuracy: 0.8923
# Epoch 2/20
# 37/37 [==============================] - 440s 12s/step - loss: 0.0929 - accuracy: 0.9692 - val_loss: 0.2358 - val_accuracy: 0.9077
# Epoch 3/20
# 37/37 [==============================] - 396s 11s/step - loss: 0.0372 - accuracy: 0.9949 - val_loss: 0.1665 - val_accuracy: 0.9231
# Epoch 4/20
# 37/37 [==============================] - 401s 11s/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9231
# Epoch 5/20
# 37/37 [==============================] - 394s 11s/step - loss: 0.0169 - accuracy: 0.9966 - val_loss: 0.1628 - val_accuracy: 0.9385
# Epoch 6/20
# 37/37 [==============================] - 398s 11s/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9231
# Epoch 7/20
# 37/37 [==============================] - 396s 11s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9385
# Epoch 8/20
# 37/37 [==============================] - 394s 11s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9231
# Epoch 9/20
# 37/37 [==============================] - 398s 11s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9385
# Epoch 10/20
# 37/37 [==============================] - 400s 11s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9385
# Epoch 11/20
# 37/37 [==============================] - 396s 11s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9231
# Epoch 12/20
# 37/37 [==============================] - 398s 11s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9231
# Epoch 13/20
# 37/37 [==============================] - 397s 11s/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9385
# Epoch 14/20
# 37/37 [==============================] - 397s 11s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9385
# Epoch 15/20
# 37/37 [==============================] - 398s 11s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9385
# Epoch 16/20
# 37/37 [==============================] - 396s 11s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9385
# Epoch 17/20
# 37/37 [==============================] - 393s 11s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9385
# Epoch 18/20
# 37/37 [==============================] - 400s 11s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9385
# Epoch 19/20
# 37/37 [==============================] - 389s 11s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9385
# Epoch 20/20
# 37/37 [==============================] - 394s 11s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9385

# %%
performance_dict = history.history
print(performance_dict.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # Check The Learning Curves

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
plt.plot(performance_dict ['loss'], color='purple', label='Train Loss')
plt.plot(performance_dict ['val_loss'], color='orange', label='Validation Loss')
plt.legend(loc='upper right', fontsize=20)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.grid(color='blue', linewidth=0.3, linestyle='--')
plt.title('Train Loss vs Validation Loss', fontsize=16)

plt.subplot(1,2,2)
plt.plot(performance_dict ['accuracy'], color='purple', label='Train Accuracy')
plt.plot(performance_dict ['val_accuracy'], color='orange', label='Validation Accuracy')
plt.legend(loc='lower right', fontsize=20)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.grid(color='blue', linewidth=0.3, linestyle='--')
plt.title('Train Accuracy vs Validation Accuracy', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Train Accuracy vs Validation Accuracy')

# %% [markdown]
# # Evaluate The Model On Validation Set

# %%
scores = model.evaluate(x_val, y_val)
# print(model.metrics_names)
print('Evaluating The Model On Validation Data')
print(model.metrics_names[1], scores[1]*100)
# Out:
# 3/3 [==============================] - 38s 10s/step - loss: 0.1506 - accuracy: 0.9385
# Evaluating The Model On Validation Data
# accuracy 93.84615421295166

# %% [markdown]
# # Check What the model actually predicts In Validation Data

# %%
plt.imshow(x_val[26])
print(y_val[26])
# Out:
# 1

# %% [markdown]
# # Check What the model predicts in Test data

# %%
prediction = model.predict(x_test)
# Out:
# 6/6 [==============================] - 96s 15s/step

# %%
prediction[1]
# Out:
# array([0.80692065, 0.04840714], dtype=float32)

# %%
y_test[1]
# Out:
# 0

# %%
y_predicted = []
# length = prediction.shape[0]
for i in range(prediction.shape[0]):
  if(prediction[i][0] > prediction[i][1]):
    y_predicted.append(0)
  else:
    y_predicted.append(1)

y_predicted_text = []
for i in range(len(y_predicted)):
  if(y_predicted[i] == 0):
    y_predicted_text.append('Peace')
  else:
    y_predicted_text.append('Thumbs Up')

# %%
plt.imshow(x_test[20])
print(y_predicted_text[20])
# Out:
# Thumbs Up

# %% [markdown]
# # Evaluate The Model On Test Set

# %%
scores = model.evaluate(x_test, y_test)
# print(model.metrics_names)
print('Evaluating The Model On Test Data')
print(model.metrics_names[0], scores[0]*100)
print(model.metrics_names[1], scores[1]*100)
# Out:
# 6/6 [==============================] - 98s 16s/step - loss: 0.2921 - accuracy: 0.8696
# Evaluating The Model On Test Data
# loss 29.211977124214172
# accuracy 86.95651888847351

# %% [markdown]
# # Confussion Matrix Of CNN Based Classifier

# %%
y_predicted
actual = y_test
conf_mat = confusion_matrix(actual, y_predicted)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat)
displ.plot(fontsize=16)

# %% [markdown]
# # Resnet

# %%
NUM_CLASSES = 2
model = Sequential()
model.add(ResNet50(include_top=False, pooling='max', weights="imagenet"))
model.add(Dense(NUM_CLASSES, activation='softmax'))
# ResNet-50 model is already trained, should not be trained
model.layers[0].trainable = False
model.compile(optimizer=keras.optimizers.Adam(
    learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dense_26 (Dense)            (None, 2)                 4098
#
# =================================================================
# Total params: 23591810 (90.00 MB)
# Trainable params: 4098 (16.01 KB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
# Plot and display the model architecture in the notebook
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# Convert labels to one-hot encoding
num_classes = 2
y_train_onehot = to_categorical(y_train, num_classes=num_classes)
y_val_onehot = to_categorical(y_val, num_classes=num_classes)
y_test_onehot = to_categorical(y_test, num_classes=num_classes)

# %%
history = model.fit(x_train, y_train_onehot, epochs=100, validation_data=(x_val, y_val_onehot), batch_size=32)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 7s 195ms/step - loss: 0.7002 - accuracy: 0.5556 - val_loss: 0.6981 - val_accuracy: 0.6000
# Epoch 2/100
# 19/19 [==============================] - 2s 111ms/step - loss: 0.5667 - accuracy: 0.6974 - val_loss: 0.6039 - val_accuracy: 0.6769
# Epoch 3/100
# 19/19 [==============================] - 2s 112ms/step - loss: 0.4652 - accuracy: 0.7675 - val_loss: 0.5451 - val_accuracy: 0.7385
# Epoch 4/100
# 19/19 [==============================] - 2s 112ms/step - loss: 0.4276 - accuracy: 0.7949 - val_loss: 0.5053 - val_accuracy: 0.7846
# Epoch 5/100
# 19/19 [==============================] - 2s 112ms/step - loss: 0.4125 - accuracy: 0.8239 - val_loss: 0.4885 - val_accuracy: 0.7846
# Epoch 6/100
# 19/19 [==============================] - 2s 112ms/step - loss: 0.4036 - accuracy: 0.8222 - val_loss: 0.5157 - val_accuracy: 0.7846
# Epoch 7/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.3982 - accuracy: 0.8205 - val_loss: 0.4750 - val_accuracy: 0.7846
# Epoch 8/100
# 19/19 [==============================] - 2s 112ms/step - loss: 0.3842 - accuracy: 0.8325 - val_loss: 0.4688 - val_accuracy: 0.7846
# Epoch 9/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.3761 - accuracy: 0.8325 - val_loss: 0.4689 - val_accuracy: 0.8308
# Epoch 10/100
# 19/19 [==============================] - 2s 113ms/step - loss: 0.3695 - accuracy: 0.8462 - val_loss: 0.4541 - val_accuracy: 0.8308
# Epoch 11/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.3669 - accuracy: 0.8462 - val_loss: 0.4531 - val_accuracy: 0.8462
# Epoch 12/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.3541 - accuracy: 0.8479 - val_loss: 0.4541 - val_accuracy: 0.8462
# Epoch 13/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.3514 - accuracy: 0.8444 - val_loss: 0.4422 - val_accuracy: 0.8462
# Epoch 14/100
# 19/19 [==============================] - 2s 112ms/step - loss: 0.3367 - accuracy: 0.8632 - val_loss: 0.4497 - val_accuracy: 0.8308
# Epoch 15/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.3419 - accuracy: 0.8513 - val_loss: 0.4321 - val_accuracy: 0.8154
# Epoch 16/100
# 19/19 [==============================] - 2s 113ms/step - loss: 0.3277 - accuracy: 0.8684 - val_loss: 0.4241 - val_accuracy: 0.8154
# Epoch 17/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.3199 - accuracy: 0.8684 - val_loss: 0.4321 - val_accuracy: 0.8462
# Epoch 18/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.3187 - accuracy: 0.8786 - val_loss: 0.4092 - val_accuracy: 0.8308
# Epoch 19/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.3098 - accuracy: 0.8684 - val_loss: 0.4064 - val_accuracy: 0.8308
# Epoch 20/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.3619 - accuracy: 0.8291 - val_loss: 0.5011 - val_accuracy: 0.7231
# Epoch 21/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.3201 - accuracy: 0.8513 - val_loss: 0.5670 - val_accuracy: 0.8000
# Epoch 22/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.3471 - accuracy: 0.8256 - val_loss: 0.4213 - val_accuracy: 0.8154
# Epoch 23/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.3170 - accuracy: 0.8650 - val_loss: 0.3993 - val_accuracy: 0.8462
# Epoch 24/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.3099 - accuracy: 0.8564 - val_loss: 0.4050 - val_accuracy: 0.8154
# Epoch 25/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.2974 - accuracy: 0.8718 - val_loss: 0.3994 - val_accuracy: 0.8308
# Epoch 26/100
# 19/19 [==============================] - 2s 117ms/step - loss: 0.2917 - accuracy: 0.9026 - val_loss: 0.3932 - val_accuracy: 0.8308
# Epoch 27/100
# 19/19 [==============================] - 2s 113ms/step - loss: 0.2920 - accuracy: 0.8855 - val_loss: 0.4087 - val_accuracy: 0.8154
# Epoch 28/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.2796 - accuracy: 0.8991 - val_loss: 0.3866 - val_accuracy: 0.8308
# Epoch 29/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.2706 - accuracy: 0.8957 - val_loss: 0.4157 - val_accuracy: 0.8308
# Epoch 30/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.2885 - accuracy: 0.8786 - val_loss: 0.3995 - val_accuracy: 0.8308
# Epoch 31/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.3324 - accuracy: 0.8632 - val_loss: 0.4290 - val_accuracy: 0.7846
# Epoch 32/100
# 19/19 [==============================] - 2s 116ms/step - loss: 0.2970 - accuracy: 0.8718 - val_loss: 0.4071 - val_accuracy: 0.8308
# Epoch 33/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.2605 - accuracy: 0.9060 - val_loss: 0.3897 - val_accuracy: 0.8615
# Epoch 34/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.2537 - accuracy: 0.9060 - val_loss: 0.3897 - val_accuracy: 0.8308
# Epoch 35/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.2558 - accuracy: 0.8957 - val_loss: 0.3636 - val_accuracy: 0.8462
# Epoch 36/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.2710 - accuracy: 0.8991 - val_loss: 0.3660 - val_accuracy: 0.8308
# Epoch 37/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.2696 - accuracy: 0.8838 - val_loss: 0.3854 - val_accuracy: 0.8462
# Epoch 38/100
# 19/19 [==============================] - 2s 116ms/step - loss: 0.2394 - accuracy: 0.9231 - val_loss: 0.3881 - val_accuracy: 0.8615
# Epoch 39/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.2435 - accuracy: 0.9128 - val_loss: 0.3714 - val_accuracy: 0.8923
# Epoch 40/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.2376 - accuracy: 0.9111 - val_loss: 0.3758 - val_accuracy: 0.8308
# Epoch 41/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.2577 - accuracy: 0.8940 - val_loss: 0.4089 - val_accuracy: 0.8462
# Epoch 42/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.2483 - accuracy: 0.8991 - val_loss: 0.3620 - val_accuracy: 0.8769
# Epoch 43/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.2392 - accuracy: 0.9043 - val_loss: 0.3589 - val_accuracy: 0.8308
# Epoch 44/100
# 19/19 [==============================] - 2s 117ms/step - loss: 0.2430 - accuracy: 0.9094 - val_loss: 0.4535 - val_accuracy: 0.8308
# Epoch 45/100
# 19/19 [==============================] - 2s 123ms/step - loss: 0.2383 - accuracy: 0.9026 - val_loss: 0.3592 - val_accuracy: 0.8308
# Epoch 46/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.2198 - accuracy: 0.9282 - val_loss: 0.3534 - val_accuracy: 0.8769
# Epoch 47/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.2180 - accuracy: 0.9179 - val_loss: 0.3478 - val_accuracy: 0.8462
# Epoch 48/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.2240 - accuracy: 0.9145 - val_loss: 0.3493 - val_accuracy: 0.8308
# Epoch 49/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.2220 - accuracy: 0.9214 - val_loss: 0.3476 - val_accuracy: 0.8462
# Epoch 50/100
# 19/19 [==============================] - 2s 116ms/step - loss: 0.2076 - accuracy: 0.9282 - val_loss: 0.3597 - val_accuracy: 0.8308
# Epoch 51/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.2341 - accuracy: 0.9077 - val_loss: 0.3836 - val_accuracy: 0.8462
# Epoch 52/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.2144 - accuracy: 0.9265 - val_loss: 0.3668 - val_accuracy: 0.8615
# Epoch 53/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.2141 - accuracy: 0.9214 - val_loss: 0.3548 - val_accuracy: 0.8308
# Epoch 54/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.2191 - accuracy: 0.9145 - val_loss: 0.3756 - val_accuracy: 0.8462
# Epoch 55/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.2205 - accuracy: 0.9197 - val_loss: 0.3430 - val_accuracy: 0.8923
# Epoch 56/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.2144 - accuracy: 0.9214 - val_loss: 0.3401 - val_accuracy: 0.8615
# Epoch 57/100
# 19/19 [==============================] - 2s 120ms/step - loss: 0.2149 - accuracy: 0.9282 - val_loss: 0.3387 - val_accuracy: 0.8923
# Epoch 58/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.1980 - accuracy: 0.9248 - val_loss: 0.3465 - val_accuracy: 0.8308
# Epoch 59/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.1892 - accuracy: 0.9436 - val_loss: 0.3524 - val_accuracy: 0.8308
# Epoch 60/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.2027 - accuracy: 0.9231 - val_loss: 0.3349 - val_accuracy: 0.8923
# Epoch 61/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.1867 - accuracy: 0.9316 - val_loss: 0.3306 - val_accuracy: 0.8769
# Epoch 62/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.1894 - accuracy: 0.9282 - val_loss: 0.3287 - val_accuracy: 0.8615
# Epoch 63/100
# 19/19 [==============================] - 2s 118ms/step - loss: 0.1909 - accuracy: 0.9402 - val_loss: 0.3369 - val_accuracy: 0.8923
# Epoch 64/100
# 19/19 [==============================] - 2s 116ms/step - loss: 0.1919 - accuracy: 0.9350 - val_loss: 0.3850 - val_accuracy: 0.8000
# Epoch 65/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.2152 - accuracy: 0.9231 - val_loss: 0.3539 - val_accuracy: 0.8769
# Epoch 66/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.2053 - accuracy: 0.9265 - val_loss: 0.3543 - val_accuracy: 0.8615
# Epoch 67/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.1812 - accuracy: 0.9299 - val_loss: 0.3313 - val_accuracy: 0.9077
# Epoch 68/100
# 19/19 [==============================] - 2s 113ms/step - loss: 0.1832 - accuracy: 0.9368 - val_loss: 0.3240 - val_accuracy: 0.8923
# Epoch 69/100
# 19/19 [==============================] - 2s 118ms/step - loss: 0.1761 - accuracy: 0.9419 - val_loss: 0.3301 - val_accuracy: 0.9077
# Epoch 70/100
# 19/19 [==============================] - 2s 117ms/step - loss: 0.1762 - accuracy: 0.9453 - val_loss: 0.3229 - val_accuracy: 0.8308
# Epoch 71/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.1955 - accuracy: 0.9333 - val_loss: 0.3458 - val_accuracy: 0.8615
# Epoch 72/100
# 19/19 [==============================] - 2s 114ms/step - loss: 0.1763 - accuracy: 0.9436 - val_loss: 0.3170 - val_accuracy: 0.8769
# Epoch 73/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.1717 - accuracy: 0.9419 - val_loss: 0.3255 - val_accuracy: 0.9077
# Epoch 74/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1741 - accuracy: 0.9350 - val_loss: 0.3142 - val_accuracy: 0.8769
# Epoch 75/100
# 19/19 [==============================] - 2s 120ms/step - loss: 0.1763 - accuracy: 0.9402 - val_loss: 0.3285 - val_accuracy: 0.9077
# Epoch 76/100
# 19/19 [==============================] - 2s 117ms/step - loss: 0.1673 - accuracy: 0.9556 - val_loss: 0.3222 - val_accuracy: 0.8154
# Epoch 77/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.1654 - accuracy: 0.9436 - val_loss: 0.3364 - val_accuracy: 0.8154
# Epoch 78/100
# 19/19 [==============================] - 2s 116ms/step - loss: 0.1790 - accuracy: 0.9436 - val_loss: 0.3284 - val_accuracy: 0.9077
# Epoch 79/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1686 - accuracy: 0.9504 - val_loss: 0.3087 - val_accuracy: 0.8615
# Epoch 80/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.1619 - accuracy: 0.9470 - val_loss: 0.3306 - val_accuracy: 0.8154
# Epoch 81/100
# 19/19 [==============================] - 2s 117ms/step - loss: 0.1679 - accuracy: 0.9453 - val_loss: 0.3557 - val_accuracy: 0.8615
# Epoch 82/100
# 19/19 [==============================] - 2s 113ms/step - loss: 0.1633 - accuracy: 0.9419 - val_loss: 0.3063 - val_accuracy: 0.8462
# Epoch 83/100
# 19/19 [==============================] - 2s 116ms/step - loss: 0.1603 - accuracy: 0.9385 - val_loss: 0.3832 - val_accuracy: 0.8462
# Epoch 84/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1829 - accuracy: 0.9350 - val_loss: 0.3109 - val_accuracy: 0.8923
# Epoch 85/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.1548 - accuracy: 0.9521 - val_loss: 0.3067 - val_accuracy: 0.8923
# Epoch 86/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1716 - accuracy: 0.9402 - val_loss: 0.3346 - val_accuracy: 0.8923
# Epoch 87/100
# 19/19 [==============================] - 2s 116ms/step - loss: 0.1524 - accuracy: 0.9504 - val_loss: 0.3128 - val_accuracy: 0.8615
# Epoch 88/100
# 19/19 [==============================] - 2s 117ms/step - loss: 0.1744 - accuracy: 0.9385 - val_loss: 0.3073 - val_accuracy: 0.8615
# Epoch 89/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.1474 - accuracy: 0.9556 - val_loss: 0.3090 - val_accuracy: 0.8154
# Epoch 90/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1552 - accuracy: 0.9487 - val_loss: 0.3007 - val_accuracy: 0.8615
# Epoch 91/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1614 - accuracy: 0.9556 - val_loss: 0.2997 - val_accuracy: 0.8923
# Epoch 92/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.1466 - accuracy: 0.9573 - val_loss: 0.3120 - val_accuracy: 0.9077
# Epoch 93/100
# 19/19 [==============================] - 2s 116ms/step - loss: 0.1619 - accuracy: 0.9470 - val_loss: 0.3215 - val_accuracy: 0.9077
# Epoch 94/100
# 19/19 [==============================] - 2s 121ms/step - loss: 0.1601 - accuracy: 0.9453 - val_loss: 0.3062 - val_accuracy: 0.8308
# Epoch 95/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1805 - accuracy: 0.9299 - val_loss: 0.3837 - val_accuracy: 0.8615
# Epoch 96/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.1492 - accuracy: 0.9504 - val_loss: 0.3043 - val_accuracy: 0.8923
# Epoch 97/100
# 19/19 [==============================] - 2s 116ms/step - loss: 0.1375 - accuracy: 0.9538 - val_loss: 0.3098 - val_accuracy: 0.8923
# Epoch 98/100
# 19/19 [==============================] - 2s 115ms/step - loss: 0.1398 - accuracy: 0.9556 - val_loss: 0.2993 - val_accuracy: 0.8615
# Epoch 99/100
# 19/19 [==============================] - 2s 111ms/step - loss: 0.1359 - accuracy: 0.9658 - val_loss: 0.3000 - val_accuracy: 0.8923
# Epoch 100/100
# 19/19 [==============================] - 2s 119ms/step - loss: 0.1342 - accuracy: 0.9573 - val_loss: 0.3036 - val_accuracy: 0.8615

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
plt.plot(performance_dict ['loss'], color='purple', label='Train Loss')
plt.plot(performance_dict ['val_loss'], color='orange', label='Validation Loss')
plt.legend(loc='upper right', fontsize=20)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.grid(color='blue', linewidth=0.3, linestyle='--')
plt.title('Train Loss vs Validation Loss', fontsize=16)

plt.subplot(1,2,2)
plt.plot(performance_dict ['accuracy'], color='purple', label='Train Accuracy')
plt.plot(performance_dict ['val_accuracy'], color='orange', label='Validation Accuracy')
plt.legend(loc='lower right', fontsize=20)
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Accuracy', fontsize=14)
plt.grid(color='blue', linewidth=0.3, linestyle='--')
plt.title('Train Accuracy vs Validation Accuracy', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Train Accuracy vs Validation Accuracy')

# %%
scores = model.evaluate(x_test, y_test_onehot)
# print(model.metrics_names)
print('Evaluating The Model On Test Data')
print(model.metrics_names[0], scores[0]*100)
print(model.metrics_names[1], scores[1]*100)
# Out:
# 6/6 [==============================] - 1s 84ms/step - loss: 0.6153 - accuracy: 0.7640
# Evaluating The Model On Test Data
# loss 61.53322458267212
# accuracy 76.39751434326172

# %%
prediction = model.predict(x_test)
# Out:
# 6/6 [==============================] - 2s 91ms/step

# %%
y_predicted = []
# length = prediction.shape[0]
for i in range(prediction.shape[0]):
  if(prediction[i][0] > prediction[i][1]):
    y_predicted.append(0)
  else:
    y_predicted.append(1)

# %%
y_predicted
actual = y_test
conf_mat = confusion_matrix(actual, y_predicted)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat)
# Increase the font size using the display_labels parameter
displ.plot(xticks_rotation='horizontal', values_format=".0f")

# Increase the font size of the labels
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Increase the font size of the xlabel and ylabel
plt.xlabel('Predicted Labels', fontsize=14)
plt.ylabel('True Labels', fontsize=14)

# Show the plot
plt.show()
